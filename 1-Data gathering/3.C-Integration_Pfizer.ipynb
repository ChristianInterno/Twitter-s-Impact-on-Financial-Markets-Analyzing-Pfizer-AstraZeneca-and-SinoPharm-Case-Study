# %% [markdown]
# # Setup

# %%
import pandas as pd
import os
import datetime
import matplotlib.pyplot as plt
import numpy as np
#!pip install sql
#!pip uninstall pandasql

#pip install vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
#pip install sklearn.preprocessing
#pip install sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing

# %% [markdown]
# # Import data

# %%
os.chdir(os.getcwd())
work_folder = "C:\\Users\\Utente\\Esercitazioni DataMan\\Dm_project\\Scripts\\DataMan_project\\Work26\\Pfe\\"

# %%
tweet_sino = pd.read_csv(work_folder+'pfe_tweet.csv')
sino = pd.read_csv(work_folder+'df_pfe.csv')
sino_b = pd.read_csv(work_folder+'df_pfe.csv')
#tweet_sino_b = pd.read_csv(work_folder+'sinopharm1.1.csv')

tweet_sino
# Out:
#                               data        location                   id  \
# 0        2021-05-24 23:59:51+00:00       Clyde, NJ  1396979289866870786
# 1        2021-05-24 23:59:48+00:00       Australia  1396979276084236289
# 2        2021-05-24 23:59:43+00:00         florida  1396979253074354176
# 3        2021-05-24 23:59:42+00:00             NaN  1396979250427613184
# 4        2021-05-24 23:59:42+00:00  Los Angeles CA  1396979250150838276
# ...                            ...             ...                  ...
# 1016645  2021-04-01 00:00:04+00:00     Bedford, TX  1377410396303200258
# 1016646  2021-04-01 00:00:02+00:00    Florida, USA  1377410388317282304
# 1016647  2021-04-01 00:00:00+00:00   Eastern Idaho  1377410382701076483
# 1016648  2021-04-01 00:00:00+00:00       Omaha, NE  1377410381086347267
# 1016649  2021-04-01 00:00:00+00:00       Omaha, NE  1377410380981501956
#
#                                                      testo         username  \
# 0        hood_medicine: We are LIVE! #Pfizer approved t...  PoliticalSphinx
# 1        @gemcarey I thought I was going mad - yes.  Pf...    DrKate_Miller
# 2        Our 16 yr old got her second Pfizer vaccine la...     jbrady200345
# 3        @NyrsaLyn I had Pfizer, my husband had Moderna...    labountygreen
# 4        @NyrsaLyn I had Pfizer &amp; had no reaction a...      HughSchurtz
# ...                                                    ...              ...
# 1016645  Pfizer delivered 1.5 million doses of vaccines...       LiquidityL
# 1016646  @LaydiexSkull I got the Pfizer in December and...   brother_ofmine
# 1016647  Clinical trial results of Pfizer/BioNTech's CO...       localnews8
# 1016648  The Pfizer vaccine is open to residents who ar...    3NewsNowOmaha
# 1016649  As of Wednesday, Pfizer-BioNTech released prom...        FOX42KPTM
#
#          replyCount  like  retweet_count  quoteCount  quote  ... lang  \
# 0                 0     0              0           0      0  ...   en
# 1                 0     1              0           0      0  ...   en
# 2                 0     0              0           0      0  ...   en
# 3                 0     1              0           0      0  ...   en
# 4                 0     1              0           0      0  ...   en
# ...             ...   ...            ...         ...    ...  ...  ...
# 1016645           0     0              0           0      0  ...   en
# 1016646           1     2              0           0      0  ...   en
# 1016647           0     0              0           0      0  ...   en
# 1016648           0     2              0           0      0  ...   en
# 1016649           0     1              0           0      0  ...   en
#
#                                                        url coordinates place  \
# 0        https://twitter.com/PoliticalSphinx/status/139...         NaN   NaN
# 1        https://twitter.com/DrKate_Miller/status/13969...         NaN   NaN
# 2        https://twitter.com/jbrady200345/status/139697...         NaN   NaN
# 3        https://twitter.com/labountygreen/status/13969...         NaN   NaN
# 4        https://twitter.com/HughSchurtz/status/1396979...         NaN   NaN
# ...                                                    ...         ...   ...
# 1016645  https://twitter.com/LiquidityL/status/13774103...         NaN   NaN
# 1016646  https://twitter.com/brother_ofmine/status/1377...         NaN   NaN
# 1016647  https://twitter.com/localnews8/status/13774103...         NaN   NaN
# 1016648  https://twitter.com/3NewsNowOmaha/status/13774...         NaN   NaN
# 1016649  https://twitter.com/FOX42KPTM/status/137741038...         NaN   NaN
#
#         followersCount  friendsCount  statusesCount  favouritesCount  \
# 0                  617           617           5821             5167
# 1                 3191          3191           8839            16457
# 2                 4191          4191          17038            27632
# 3                 2054          2054          32561            53746
# 4                 3969          3969          44881            59145
# ...                ...           ...            ...              ...
# 1016645            280           280          54319              943
# 1016646             94            94           8925            36237
# 1016647          18433         18433          56956              811
# 1016648          70437         70437          88983            14476
# 1016649          15839         15839          51598              509
#
#          listedCount  mediaCount
# 0                  2         378
# 1                 21         181
# 2                  5         521
# 3                  4          42
# 4                  4        2715
# ...              ...         ...
# 1016645            8          13
# 1016646            0        1437
# 1016647          398        6039
# 1016648          596        4167
# 1016649          349       12997
#
# [1016650 rows x 21 columns]

# %%
# Type datetime and timezone
sino['Datetime'] = pd.to_datetime(sino['Datetime'])
sino['Datetime']=sino['Datetime'].dt.tz_localize(None)

# Time delta for (+4 for timezone +1 for correlation)
hours= +5
hours_added = datetime.timedelta(hours = hours)
sino['Datetime']= sino['Datetime'] + hours_added

#sino.set_index('Datetime', inplace=True)
#sino=sino.loc["2021-04-08 00:30:00":]

# Result start
sino.head()
# Out:
#              Datetime       Open       High        Low      Close  Volume
# 0 2021-04-08 14:30:00  35.959999  35.979698  35.939999  35.959999   91369
# 1 2021-04-08 14:31:00  35.950001  36.009998  35.939999  35.991199  635255
# 2 2021-04-08 14:32:00  36.000000  36.000000  35.910000  35.930000   81408
# 3 2021-04-08 14:33:00  35.930000  35.935001  35.910000  35.919998   81883
# 4 2021-04-08 14:34:00  35.910000  36.009998  35.891998  35.970001  131283

# %%
# Result end
sino.tail()
# Out:
#                  Datetime       Open       High        Low      Close  Volume
# 12458 2021-05-21 20:55:00  40.040001  40.044998  39.990002  40.000000  468928
# 12459 2021-05-21 20:56:00  40.000000  40.005001  39.950001  39.959999  241321
# 12460 2021-05-21 20:57:00  39.955002  39.990002  39.955002  39.974998  244966
# 12461 2021-05-21 20:58:00  39.974998  39.980000  39.950001  39.959999  216200
# 12462 2021-05-21 20:59:00  39.955002  39.980000  39.910000  39.959999  788848

# %%
# Type datetime and timezone
tweet_sino['data'] = pd.to_datetime(tweet_sino['data'])
tweet_sino['data']=tweet_sino['data'].dt.tz_localize(None)

#file_tweet.set_index('data', inplace=True)
#file_tweet.index.rename('Datetime', inplace=True)
#sino['Datetime']=pd.to_datetime(sino['Datetime'],format='%H:%M')

# %% [markdown]
# # Backup for daily analysis

# %%
# Backup of tweet sino 
tweet_sino_c = tweet_sino

# %%
# Rename
tweet_sino = tweet_sino.rename(columns={'data': 'Datetime'})

# Sort
tweet_sino = tweet_sino.sort_values(by="Datetime")

#file_tweet['Datetime']=pd.to_datetime(file_tweet['Datetime'],format='%H:%M')
#file_tweet['Datetime']= df.index.map(lambda t: t.strftime('%Y-%m-%d %H:%M'))

#tweet_sino

# %%
# Delete minute and 
tweet_sino['Datetime'] = tweet_sino['Datetime'].dt.strftime('%Y-%m-%d %H')

#tweet_sino

# %%
# Change format (delete data of seconds)
#tweet_sino['Datetime'] = tweet_sino['Datetime'].values.astype('<M8[m]')
#tweet_sino['Datetime']

# %% [markdown]
# # Sentiment

# %%
analyzer = SentimentIntensityAnalyzer()
df =[]
for sentence in tweet_sino['testo']:
    vs = analyzer.polarity_scores(sentence)
    vs_df = pd.DataFrame.from_dict(vs.values(), orient='columns')
    df.append(vs_df[0][3])
    
tweet_sino['compound'] = df

tweet_sino['compound'].describe()
# Out:
# count    1.016650e+06
# mean     1.077847e-01
# std      4.439259e-01
# min     -9.992000e-01
# 25%     -7.720000e-02
# 50%      0.000000e+00
# 75%      4.588000e-01
# max      9.996000e-01
# Name: compound, dtype: float64

# %% [markdown]
# # Sino Tweet _ hourly analyzes

# %%
sino_count=pd.DataFrame()

# Count tweet by hour
sino_count['N of Tweet']= tweet_sino.groupby('Datetime')['id'].count()

# Count like ecc by hour and divide by number of tweet
sino_count['sum of Nlike']= tweet_sino.groupby('Datetime')['like'].sum()
sino_count['median of Nlike']= tweet_sino.groupby('Datetime')['like'].median()
sino_count['avg of Nlike']= tweet_sino.groupby('Datetime')['like'].sum()/sino_count['N of Tweet']
sino_count['max of Nlike']= tweet_sino.groupby('Datetime')['like'].max()#sum()#/sino_count['N of Tweet']

sino_count['sum of retweet']= tweet_sino.groupby('Datetime')['retweet_count'].sum()
sino_count['median of retweet']= tweet_sino.groupby('Datetime')['retweet_count'].median()#sum()#/sino_count['N of Tweet']
sino_count['avg of retweet']= tweet_sino.groupby('Datetime')['retweet_count'].sum()/sino_count['N of Tweet']
sino_count['max of retweet']= tweet_sino.groupby('Datetime')['retweet_count'].max()

sino_count['sum of reply']= tweet_sino.groupby('Datetime')['replyCount'].sum()
sino_count['median of reply']= tweet_sino.groupby('Datetime')['replyCount'].median()#sum()#/sino_count['N of Tweet']
sino_count['avg of reply']= tweet_sino.groupby('Datetime')['replyCount'].sum()/sino_count['N of Tweet']
sino_count['max of reply']= tweet_sino.groupby('Datetime')['replyCount'].max()

sino_count['Comp']= tweet_sino.groupby('Datetime')['compound'].sum()/sino_count['N of Tweet']

sino_count.reset_index(inplace=True)
sino_count
# Out:
#            Datetime  N of Tweet  sum of Nlike  median of Nlike  avg of Nlike  \
# 0     2021-04-01 00         802         10886              1.0     13.573566
# 1     2021-04-01 01         733          7392              1.0     10.084584
# 2     2021-04-01 02         671          4063              1.0      6.055142
# 3     2021-04-01 03         550          5514              1.0     10.025455
# 4     2021-04-01 04         415          3429              1.0      8.262651
# ...             ...         ...           ...              ...           ...
# 1291  2021-05-24 19         527          4966              1.0      9.423150
# 1292  2021-05-24 20         526          3479              1.0      6.614068
# 1293  2021-05-24 21         499          2652              1.0      5.314629
# 1294  2021-05-24 22         489          2437              1.0      4.983640
# 1295  2021-05-24 23         472         17323              1.0     36.701271
#
#       max of Nlike  sum of retweet  median of retweet  avg of retweet  \
# 0             6832             939                  0        1.170823
# 1             2670             880                  0        1.200546
# 2             1031             418                  0        0.622951
# 3             1485             779                  0        1.416364
# 4             1121             889                  0        2.142169
# ...            ...             ...                ...             ...
# 1291          3227            1831                  0        3.474383
# 1292           477             897                  0        1.705323
# 1293           469             518                  0        1.038076
# 1294           262             571                  0        1.167689
# 1295         12678            1848                  0        3.915254
#
#       max of retweet  sum of reply  median of reply  avg of reply  \
# 0                269           626                0      0.780549
# 1                285           720                0      0.982265
# 2                 90           490                0      0.730253
# 3                169           412                0      0.749091
# 4                384           388                0      0.934940
# ...              ...           ...              ...           ...
# 1291            1538           417                0      0.791271
# 1292             372           850                0      1.615970
# 1293             170           391                0      0.783567
# 1294              92           344                0      0.703476
# 1295             823           765                0      1.620763
#
#       max of reply      Comp
# 0               57  0.201664
# 1               97  0.182747
# 2               36  0.178411
# 3               32  0.156735
# 4               51  0.141419
# ...            ...       ...
# 1291            51  0.137823
# 1292           296  0.123989
# 1293            47  0.104102
# 1294            37  0.077300
# 1295           298  0.032813
#
# [1296 rows x 15 columns]

# %% [markdown]
# ### Stock data

# %%
# Delete minutes
sino['Datetime'] = sino['Datetime'].dt.strftime('%Y-%m-%d %H')
sino = sino.drop_duplicates(subset='Datetime', keep="first")
sino.head()
# Out:
#           Datetime       Open       High        Low      Close  Volume
# 0    2021-04-08 14  35.959999  35.979698  35.939999  35.959999   91369
# 30   2021-04-08 15  36.119999  36.150002  36.119999  36.145000   40275
# 90   2021-04-08 16  36.005001  36.020000  36.000000  36.014999   46592
# 150  2021-04-08 17  35.980000  35.990002  35.980000  35.980000   27403
# 210  2021-04-08 18  36.055000  36.060001  36.044998  36.055000   62088

# %%
# Merge stock data and tweet indices 
sino_int = sino.merge(sino_count, on='Datetime', how='left', indicator=False)
sino_int.head()
# Out:
#         Datetime       Open       High        Low      Close  Volume  \
# 0  2021-04-08 14  35.959999  35.979698  35.939999  35.959999   91369
# 1  2021-04-08 15  36.119999  36.150002  36.119999  36.145000   40275
# 2  2021-04-08 16  36.005001  36.020000  36.000000  36.014999   46592
# 3  2021-04-08 17  35.980000  35.990002  35.980000  35.980000   27403
# 4  2021-04-08 18  36.055000  36.060001  36.044998  36.055000   62088
#
#    N of Tweet  sum of Nlike  median of Nlike  avg of Nlike  max of Nlike  \
# 0        1404         10882              1.0      7.750712          2404
# 1        1351         11601              1.0      8.586973          1663
# 2        1337         17942              1.0     13.419596          6516
# 3        1391        166360              1.0    119.597412        121635
# 4        1277         10754              1.0      8.421300          2335
#
#    sum of retweet  median of retweet  avg of retweet  max of retweet  \
# 0            1650                  0        1.175214             438
# 1            1183                  0        0.875648             185
# 2            3334                  0        2.493642            2145
# 3           18843                  0       13.546370           16037
# 4            1540                  0        1.205951             689
#
#    sum of reply  median of reply  avg of reply  max of reply      Comp
# 0          1531                0      1.090456           343  0.101004
# 1          1197                0      0.886010            66  0.120507
# 2          1438                0      1.075542           115  0.106662
# 75%        856.000000   1662.000000              0.0      1.356387
# max      16037.000000   7856.000000              0.0      3.924076
#
#        max of reply        Comp
# count    225.000000  225.000000
# mean     318.555556    0.121316
# std      499.854852    0.023458
# min       22.000000    0.061608
# 25%       79.000000    0.103800
# 50%      168.000000    0.121291
# 75%      315.000000    0.134583
# max     4225.000000    0.234591

# %%
norm = sino_int['Comp']
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(np.array(norm).reshape(-1,1))
sino_int['Comp'] = x_scaled

# %%
sino_int.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  225.000000  225.000000  225.000000  225.000000  2.250000e+02
# mean    38.905571   38.923301   38.889007   38.906973  1.620891e+05
# std      1.201991    1.202938    1.199713    1.200998  4.648564e+05
# min     35.955002   35.959999   35.939999   35.959499  0.000000e+00
# 25%     38.500000   38.534302   38.459999   38.474998  2.855100e+04
# 50%     39.029999   39.040001   39.020000   39.033501  4.971700e+04
# 75%     39.900002   39.910000   39.849998   39.884998  1.006380e+05
# max     41.080002   41.090000   41.009998   41.035000  4.248011e+06
#
#         N of Tweet   sum of Nlike  median of Nlike  avg of Nlike  \
# count   225.000000     225.000000       225.000000    225.000000
# mean   1233.862222   16998.840000         0.857778     13.034512
# std     361.913471   22845.951967         0.350057     16.590493
# min     624.000000    3402.000000         0.000000      3.422794
# 25%    1028.000000    6956.000000         1.000000      6.413308
# 50%    1178.000000   10306.000000         1.000000      8.866929
# 75%    1357.000000   16314.000000         1.000000     12.826979
# max    2668.000000  189743.000000         1.000000    170.559188
#
#         max of Nlike  sum of retweet  median of retweet  avg of retweet  \
# count     225.000000      225.000000              225.0      225.000000
# mean     6466.391111     2803.688889                0.0        2.088523
# std     16193.289119     3620.087510                0.0        2.183081
# min       182.000000      467.000000                0.0        0.490233
# 25%       952.000000     1073.000000                0.0        0.988536
# 50%      2095.000000     1621.000000                0.0        1.398230
# 75%      5265.000000     2812.000000                0.0        2.214286
# max    145900.000000    24496.000000                0.0       16.096465
#
#        max of retweet  sum of reply  median of reply  avg of reply  \
# count      225.000000    225.000000            225.0    225.000000
# mean      1062.266667   1524.524444              0.0      1.202509
# std       2164.058095    949.854599              0.0      0.509723
# min         52.000000    514.000000              0.0      0.555147
# 25%        188.000000    970.000000              0.0      0.864486
# 50%        369.000000   1203.000000              0.0      1.051921
# 75%        856.000000   1662.000000              0.0      1.356387
# max      16037.000000   7856.000000              0.0      3.924076
#
#        max of reply        Comp
# count    225.000000  225.000000
# mean     318.555556    0.345170
# std      499.854852    0.135607
# min       22.000000    0.000000
# 25%       79.000000    0.243906
# 50%      168.000000    0.345021
# 75%      315.000000    0.421861
# max     4225.000000    1.000000

# %% [markdown]
# # Save Data

# %%
sino_int['Datetime'] = pd.to_datetime(sino_int['Datetime'])
sino_int['Date'] = pd.to_datetime(sino_int['Datetime']).dt.date
sino_int['Date'] = pd.to_datetime(sino_int['Date'])
sino_int.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 225 entries, 0 to 224
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Datetime           225 non-null    datetime64[ns]
#  1   Open               225 non-null    float64
#  2   High               225 non-null    float64
#  3   Low                225 non-null    float64
#  4   Close              225 non-null    float64
#  5   Volume             225 non-null    int64
#  6   N of Tweet         225 non-null    int64
#  7   sum of Nlike       225 non-null    int64
#  8   median of Nlike    225 non-null    float64
#  9   avg of Nlike       225 non-null    float64
#  10  max of Nlike       225 non-null    int64
#  11  sum of retweet     225 non-null    int64
#  12  median of retweet  225 non-null    int64
#  13  avg of retweet     225 non-null    float64
#  14  max of retweet     225 non-null    int64
#  15  sum of reply       225 non-null    int64
#  16  median of reply    225 non-null    int64
#  17  avg of reply       225 non-null    float64
#  18  max of reply       225 non-null    int64
#  19  Comp               225 non-null    float64
#  20  Date               225 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), float64(9), int64(10)
# memory usage: 38.7 KB

# %%
os.chdir(os.getcwd())
work_folder = "C:\\Users\\Utente\\Esercitazioni DataMan\\Dm_project\\Scripts\\DataMan_project\\Dataset_integrati\\Pfe\\"
sino_int.to_csv(work_folder+'pfe_H_integrato.csv', sep=';')

# %% [markdown]
# # Daily analysis

# %%
# Type datetime and timezone
sino_b['Datetime'] = pd.to_datetime(sino_b['Datetime'])
sino_b['Datetime']=sino_b['Datetime'].dt.tz_localize(None)

# Time delta for (-8 for timezone)
hours= +4
hours_added = datetime.timedelta(hours = hours)
sino_b['Datetime']= sino_b['Datetime'] + hours_added

#sino.set_index('Datetime', inplace=True)
#sino=sino.loc["2021-04-08 00:30:00":]

# Result start
sino_b.head()
# Out:
#              Datetime       Open       High        Low      Close  Volume
# 0 2021-04-08 13:30:00  35.959999  35.979698  35.939999  35.959999   91369
# 1 2021-04-08 13:31:00  35.950001  36.009998  35.939999  35.991199  635255
# 2 2021-04-08 13:32:00  36.000000  36.000000  35.910000  35.930000   81408
# 3 2021-04-08 13:33:00  35.930000  35.935001  35.910000  35.919998   81883
# 4 2021-04-08 13:34:00  35.910000  36.009998  35.891998  35.970001  131283

# %%
sino_b.tail()
# Out:
#                  Datetime       Open       High        Low      Close  Volume
# 12458 2021-05-21 19:55:00  40.040001  40.044998  39.990002  40.000000  468928
# 12459 2021-05-21 19:56:00  40.000000  40.005001  39.950001  39.959999  241321
# 12460 2021-05-21 19:57:00  39.955002  39.990002  39.955002  39.974998  244966
# 12461 2021-05-21 19:58:00  39.974998  39.980000  39.950001  39.959999  216200
# 12462 2021-05-21 19:59:00  39.955002  39.980000  39.910000  39.959999  788848

# %%
# Time delta for time interval
hours= +44 #+32   #+24
hours_added = datetime.timedelta(hours = hours)
tweet_sino_c['data']= tweet_sino_c['data'] + hours_added

# Rename
tweet_sino_c = tweet_sino_c.rename(columns={'data': 'Datetime'})

# Sort
tweet_sino_c = tweet_sino_c.sort_values(by="Datetime")

# Delete hour and minutes
tweet_sino_c['date'] = pd.to_datetime(tweet_sino_c['Datetime']).dt.date

# Create column for number of day (0 is Sunday, 6 is Saturday)
tweet_sino_c['day_of_week'] = tweet_sino_c['Datetime'].dt.strftime('%w')

# %%
# Add a day on for every Sunday
hours=+24
hours_added = datetime.timedelta(hours = hours)

tweet_sino_c['Datetime'] = np.where(
    tweet_sino_c['day_of_week'] == '0',tweet_sino_c['Datetime']+hours_added,tweet_sino_c['Datetime'])

# Add two day on for every Saturday
hours=+48
hours_added = datetime.timedelta(hours = hours)

tweet_sino_c['Datetime'] = np.where(
    tweet_sino_c['day_of_week'] == '6',tweet_sino_c['Datetime']+hours_added,tweet_sino_c['Datetime'])

# %%
# Sunday on Monday
tweet_sino_c[tweet_sino_c['day_of_week']=='0']
# Out:
#                   Datetime                       location  \
# 994401 2021-04-05 00:00:02                      Miami, FL
# 994400 2021-04-05 00:00:03                    Seattle, WA
# 994399 2021-04-05 00:00:06                            NaN
# 994398 2021-04-05 00:00:08                            NaN
# 994397 2021-04-05 00:00:10  A lovely life~Seattle & Tokyo
# ...                    ...                            ...
# 36159  2021-05-24 23:59:25                            NaN
# 36158  2021-05-24 23:59:36                         Mumbai
# 36157  2021-05-24 23:59:40                         Canada
# 36156  2021-05-24 23:59:50                 Wisconsin, USA
# 36155  2021-05-24 23:59:52                            NaN
#
#                          id  \
# 994401  1377833175733444609
# 994400  1377833178874871813
# 994399  1377833193596887045
# 994398  1377833201494728705
# 994397  1377833208780230661
# ...                     ...
# 36159   1395952413207580682
# 36158   1395952457683927042
# 36157   1395952477422473217
# 36156   1395952518933450761
# 36155   1395952526332026888
#
#                                                     testo        username  \
# 994401  Just secured an appointment to get Miss Pfizer...   fioredeicieli
# 994400  @DanaDDeree 💯 agree! Got my second Pfizer dose...        WestonJK
# 994399  @SParnis @phbarratt I think I’ll hold out for ...     GlennColgan
# 994398  Feeling rejuvenated! First dose of the Pfizer ...  stevebrashear2
# 994397  @critigal1 Haven’t got my first yet.... soon t...    Lovelylanvin
# ...                                                   ...             ...
# 36159   @SharonJWright1 Vaccinated and still masking, ...           dreux
# 36158   @QuintHindi @sanjaypugalia Agree Blocking Glob...       manojtjha
# 36157   @lisascmenard @NaTAlay__GF We recommend not bo...   VaxHuntersCan
# 36156   @Briankmcneal @highazzaquarius So far the data...           cnute
# 36155   @kfunk937 @agnesjuliet Made a back up plan in ...       auscandoc
#
#         replyCount  like  retweet_count  quoteCount  quote  ...  \
# 994401           1    62              0           0      0  ...
# 994400           0     2              0           0      0  ...
# 994399           2     2              1           0      0  ...
# 994398           0     7              0           0      0  ...
# 994397           0     3              0           0      0  ...
# ...            ...   ...            ...         ...    ...  ...
# 36159            2    23              1           0      0  ...
# 36158            0     0              0           0      0  ...
# 36157            0     2              0           0      0  ...
# 36156            1     1              1           0      0  ...
# 36155            1     3              0           0      0  ...
#
#                                               coordinates  \
# 994401                                                NaN
# 994400                                                NaN
# 994399                                                NaN
# 994398                                                NaN
# 994397                                                NaN
# ...                                                   ...
# 36159                                                 NaN
# 36158   Coordinates(longitude=72.74484, latitude=18.84...
# 36157                                                 NaN
# 36156                                                 NaN
# 36155                                                 NaN
#
#                                                     place followersCount  \
# 994401                                                NaN          13139
# 994400                                                NaN          10606
# 994399                                                NaN            114
# 994398                                                NaN             76
# 994397                                                NaN           5266
# ...                                                   ...            ...
# 36159                                                 NaN           2461
# 36158   Place(fullName='Mumbai, India', name='Mumbai',...            221
# 36157                                                 NaN         264395
# 36156                                                 NaN           1141
# 36155                                                 NaN           1309
#
#        friendsCount statusesCount  favouritesCount  listedCount  mediaCount  \
# 994401        13139         14002            96501           26         913
# 994400        10606         45942            32374            7       11733
# 994399          114          6535             3710            2        1096
# 994398           76            94              204            1          12
# 994397         5266        298701            97785          323       18543
# ...             ...           ...              ...          ...         ...
# 36159          2461         10113            77094            8         516
# 36158           221         21991            29174            1         975
# 36157        264395          6674             5716          402        1534
# 36156          1141         20920            97866           11        1466
# 36155          1309         20059            42955           27        1920
#
#               date  day_of_week
# 994401  2021-04-04            0
# 994400  2021-04-04            0
# 994399  2021-04-04            0
# 994398  2021-04-04            0
# 994397  2021-04-04            0
# ...            ...          ...
# 36159   2021-05-23            0
# 36158   2021-05-23            0
# 36157   2021-05-23            0
# 36156   2021-05-23            0
# 36155   2021-05-23            0
#
# [161958 rows x 23 columns]

# %%
# Saturday on Monday
tweet_sino_c[tweet_sino_c['day_of_week']=='6']
# Out:
#                    Datetime              location                   id  \
# 1013893 2021-04-05 00:00:04  Coachella Valley, CA  1377470797137260544
# 1013892 2021-04-05 00:00:05      Greenville, S.C.  1377470800647884804
# 1013891 2021-04-05 00:00:07          Atlanta, Ga.  1377470807232897034
# 1013890 2021-04-05 00:00:11                   NaN  1377470822948855812
# 1013889 2021-04-05 00:00:13    Beaverton, OR, USA  1377470832188870657
# ...                     ...                   ...                  ...
# 50675   2021-05-24 23:59:40               Sevilla  1395590087749083138
# 50674   2021-05-24 23:59:45                   NaN  1395590109869662208
# 50673   2021-05-24 23:59:50               Arizona  1395590130568634375
# 50672   2021-05-24 23:59:52                 India  1395590136969109506
# 50671   2021-05-24 23:59:58               Wakanda  1395590162332143622
#
#                                                      testo         username  \
# 1013893  Would you vaccinate your child? Today Pfizer a...             KESQ
# 1013892  Pfizer/BioNTech's global goal is 2.5 billion d...  foxcarolinanews
# 1013891  Manufacturing moonshot: How Pfizer makes its m...            cbs46
# 1013890  Patient Information: Necessity of 2 Doses of t...      aussiecoley
# 1013889  @JenMsft Got my first Pfizer dose today (Oregon).         NosmoRex
# ...                                                    ...              ...
# 50675    @vonderleyen @BioNTech_Group @pfizer So diffic...        fcojperez
# 50674    Have astra Zeneca in me will prob get moderna ...       yabbie5674
# 50673    @VeronicaRaex My second Pfizer shot was a lot ...         Shahdo81
# 50672    Quarantine tourism or maybe trying to get pfiz...       rahulsoren
# 50671                 @itsbinderella U getting the Pfizer?         joshnem_
#
#          replyCount  like  retweet_count  quoteCount  quote  ... coordinates  \
# 1013893           4     6              1           0      0  ...         NaN
# 1013892           0     0              0           0      0  ...         NaN
# 1013891           0     0              1           0      0  ...         NaN
# 1013890           0     0              1           0      0  ...         NaN
# 1013889           0     0              0           0      0  ...         NaN
# ...             ...   ...            ...         ...    ...  ...         ...
# 50675             0     0              0           0      0  ...         NaN
# 50674             1     0              0           0      0  ...         NaN
# 50673             0     1              0           0      0  ...         NaN
# 50672             0     0              0           0      0  ...         NaN
# 50671             1     0              0           0      0  ...         NaN
#
#         place followersCount friendsCount statusesCount  favouritesCount  \
# 1013893   NaN          46036        46036         53841             2808
# 1013892   NaN          86463        86463        178367             1496
# 1013891   NaN          99592        99592        259256             3770
# 1013890   NaN            723          723        145442              177
# 1013889   NaN             81           81         14053             6491
# ...       ...            ...          ...           ...              ...
# 50675     NaN            328          328        455348             3404
# 50674     NaN            637          637         64956            64443
# 50673     NaN            104          104          5865            11619
# 50672     NaN            405          405         15131           151884
# 50671     NaN            292          292          9307            14217
#
#          listedCount  mediaCount        date  day_of_week
# 1013893          481        8999  2021-04-03            6
# 1013892          709       23021  2021-04-03            6
# 1013891         1741       60929  2021-04-03            6
# 1013890          326         152  2021-04-03            6
# 1013889           11         975  2021-04-03            6
# ...              ...         ...         ...          ...
# 50675             60        1536  2021-05-22            6
# 50674             25        4836  2021-05-22            6
# 50673              0         725  2021-05-22            6
# 50672              2        4098  2021-05-22            6
# 50671              0         857  2021-05-22            6
#
# [182265 rows x 23 columns]

# %% [markdown]
# ### Sentiment

# %%
analyzer = SentimentIntensityAnalyzer()
df =[]
for sentence in tweet_sino_c['testo']:
    vs = analyzer.polarity_scores(sentence)
    vs_df = pd.DataFrame.from_dict(vs.values(), orient='columns')
    df.append(vs_df[0][3])
    
tweet_sino_c['compound'] = df

# %%
tweet_sino_c['compound'].describe()
# Out:
# count    1.016650e+06
# mean     1.077847e-01
# std      4.439259e-01
# min     -9.992000e-01
# 25%     -7.720000e-02
# 50%      0.000000e+00
# 75%      4.588000e-01
# max      9.996000e-01
# Name: compound, dtype: float64

# %% [markdown]
# # Count

# %%
# Rewrite date for weekend
tweet_sino_c['date'] = pd.to_datetime(tweet_sino_c['Datetime']).dt.date

# %%
sino_count=pd.DataFrame()

# Count tweet by date 
sino_count['N of Tweet']= tweet_sino_c.groupby('date')['id'].count()
# Count like ecc
sino_count['sum of Nlike']= tweet_sino_c.groupby('date')['like'].sum()
sino_count['median of Nlike']= tweet_sino_c.groupby('date')['like'].median()
sino_count['avg of Nlike']= tweet_sino_c.groupby('date')['like'].sum()/sino_count['N of Tweet']
sino_count['max of Nlike']= tweet_sino_c.groupby('date')['like'].max()#.sum()#/sino_count['N of Tweet']

sino_count['sum of retweet']= tweet_sino_c.groupby('date')['retweet_count'].sum()
sino_count['median of retweet']= tweet_sino_c.groupby('date')['retweet_count'].median()#.sum()#/sino_count['N of Tweet']
sino_count['avg of retweet']= tweet_sino_c.groupby('date')['retweet_count'].sum()/sino_count['N of Tweet']
sino_count['max of retweet']= tweet_sino_c.groupby('date')['retweet_count'].max()

sino_count['sum of reply']= tweet_sino_c.groupby('date')['replyCount'].sum()
sino_count['median of reply']= tweet_sino_c.groupby('date')['replyCount'].median()
sino_count['avg of reply']= tweet_sino_c.groupby('date')['replyCount'].sum()/sino_count['N of Tweet']
sino_count['max of reply']= tweet_sino_c.groupby('date')['replyCount'].max()#/sino_count['N of Tweet']

sino_count['Comp']= tweet_sino_c.groupby('date')['compound'].sum()/sino_count['N of Tweet']

sino_count.reset_index(inplace=True)
sino_count = sino_count.rename(columns={'date': 'Datetime'})
sino_count
# Out:
#       Datetime  N of Tweet  sum of Nlike  median of Nlike  avg of Nlike
# 31            6230  18689.333333                0      1.015872          2073
# 32             632  10283.000000                0      0.941150           368
# 33           10237  18964.000000                0      1.240937           729
# 34            1344  22841.000000                0      1.353541          3041
# 35            1413  17946.000000                0      1.050764           549
# 36           38572  16196.666667                0      1.082737          2208
# 37            5052  17220.000000                0      1.342376           521
# 38            3501  17225.000000                0      1.391245          2117
#
#         Comp day_of_week
# 0   0.182005           5
# 1   0.155874           1
# 2   0.116346           2
# 3   0.111967           3
# 4   0.108135           4
# 5   0.085070           5
# 6   0.104830           1
# 7   0.089053           2
# 8   0.081431           3
# 9   0.094335           4
# 10  0.111101           5
# 11  0.091247           1
# 12  0.096505           2
# 13  0.110753           3
# 14  0.105690           4
# 15  0.086289           5
# 16  0.089622           1
# 17  0.065996           2
# 18  0.093782           3
# 19  0.131297           4
# 20  0.119423           5
# 21  0.103497           1
# 22  0.082013           2
# 23  0.119041           3
# 24  0.118247           4
# 25  0.123471           5
# 26  0.125330           1
# 27  0.107785           2
# 28  0.111885           3
# 29  0.103328           4
# 30  0.135427           5
# 31  0.123192           1
# 32  0.101157           2
# 33  0.100697           3
# 34  0.115748           4
# 35  0.105211           5
# 36  0.098363           1
# 37  0.140332           2
# 38  0.079189           3

# %%
# Delete hour from stock dataset
sino['Datetime'] = pd.to_datetime(sino['Datetime']).dt.date

# Drop duplicate and take only closing price 
sino = sino.drop_duplicates(subset='Datetime', keep="last")
sino.head()
# Out:
#         Datetime       Open       High        Low      Close  Volume
# 330   2021-04-08  35.955002  35.959999  35.950001  35.959499   13520
# 720   2021-04-09  36.500000  36.505001  36.490002  36.498001   26593
# 1110  2021-04-12  36.965000  36.970001  36.950001  36.963299  126606
# 1500  2021-04-13  37.105000  37.130001  37.099998  37.125000   96831
# 1889  2021-04-14  37.064999  37.070000  37.060001  37.060001   12271

# %%
sino['Datetime'] = pd.to_datetime(sino['Datetime'])

# %%
# Merge stock and daily analysis
sino_int = sino.merge(sino_count, on='Datetime', how='left', indicator=False)
sino_int.head()
# Out:
#     Datetime       Open       High        Low      Close  Volume  N of Tweet  \
# 0 2021-04-08  35.955002  35.959999  35.950001  35.959499   13520     19238.0
# 1 2021-04-09  36.500000  36.505001  36.490002  36.498001   26593     24310.0
# 2 2021-04-12  36.965000  36.970001  36.950001  36.963299  126606     24368.0
# 3 2021-04-13  37.105000  37.130001  37.099998  37.125000   96831     17309.0
# 4 2021-04-14  37.064999  37.070000  37.060001  37.060001   12271     20151.0
#
#     sum of Nlike  median of Nlike  avg of Nlike  ...  sum of retweet  \
# 0  209020.000000                1     10.864955  ...    37675.000000
# 1  235742.000000                1      9.697326  ...    28760.000000
# 2  656009.333333                1     26.920935  ...    84263.333333
# 3  155945.000000                1      9.009475  ...    27461.000000
# 4  160631.000000                1      7.971366  ...    25652.000000
#
#    median of retweet  avg of retweet  max of retweet  sum of reply  \
# 0                  0        1.958364            9409  29535.000000
# 1                  0        1.183052            1678  31880.000000
# 2                  0        3.457950           37449  29906.333333
# 3                  0        1.586516            1807  20097.000000
# 4                  0        1.272989            2500  17491.000000
#
#    median of reply  avg of reply  max of reply      Comp  day_of_week
# 0                0      1.535243          7072  0.108135            4
# 1                0      1.311394          6102  0.085070            5
# 2                0      1.227279          3314  0.104830            1
# 3                0      1.161072          2861  0.089053            2
# 4                0      0.867997           298  0.081431            3
#
# [5 rows x 21 columns]

# %%
sino_int['median of Nlike'].min()
# Out:
# 0

# %%
sino_int.describe()
# Out:
#             Open       High        Low      Close         Volume  \
# count  32.000000  32.000000  32.000000  32.000000      32.000000
# mean   38.920578  38.930244  38.910500  38.919572   86292.562500
# std     1.169507   1.169478   1.167246   1.165729  164426.826047
# min    35.955002  35.959999  35.950001  35.959499       0.000000
# 25%    38.523751  38.557501  38.522501  38.552675   16454.750000
# 50%    39.062500  39.070000  39.055000  39.067499   38495.500000
# 75%    39.887501  39.898101  39.855001  39.863424   86753.750000
# max    40.240002  40.250000  40.240002  40.244999  916496.000000
#
#          N of Tweet   sum of Nlike  median of Nlike  avg of Nlike  \
# count     32.000000      32.000000        32.000000     32.000000
# mean   19547.020833  252855.177083         0.750000     12.663530
# std     4978.511955  127596.530727         0.439941      4.608707
# min    10030.000000   93361.000000         0.000000      7.408933
# 25%    17028.000000  161352.500000         0.750000      9.276677
# 50%    19215.500000  223902.333333         1.000000     11.192285
# 75%    22640.750000  313291.750000         1.000000     15.548817
# max    34397.000000  656009.333333         1.000000     26.920935
#
#         max of Nlike  sum of retweet  median of retweet  avg of retweet  \
# count      32.000000       32.000000               32.0       32.000000
# mean    56462.875000    43643.916667                0.0        2.161129
# std     90032.685494    22429.254853                0.0        0.757289
# min      5921.000000    12130.000000                0.0        1.110196
# 25%     15631.000000    28435.250000                0.0        1.632236
# 50%     25111.500000    37697.333333                0.0        2.048869
# 75%     61623.750000    52828.000000                0.0        2.575816
# max    488479.000000   101172.000000                0.0        3.770449
#
#        max of retweet  sum of reply  median of reply  avg of reply  \
# count        32.00000     32.000000             32.0     32.000000
# mean       7216.12500  23262.125000              0.0      1.180315
# std        7431.56409   7543.819052              0.0      0.190364
# min         632.00000  10162.000000              0.0      0.867997
# 25%        2183.25000  18348.500000              0.0      1.038296
# 50%        5268.50000  21689.000000              0.0      1.148276
# 75%        9953.00000  29421.750000              0.0      1.327442
# max       37449.00000  40555.000000              0.0      1.562189
#
#        max of reply       Comp
# count     32.000000  32.000000
# mean    2373.375000   0.104393
# std     1992.696095   0.015969
# min      267.000000   0.065996
# 25%      705.750000   0.093148
# 50%     2029.000000   0.105020
# 75%     3083.000000   0.116373
# max     7630.000000   0.135427

# %%
norm = sino_int['Comp']
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(np.array(norm).reshape(-1,1))
sino_int['Comp'] = x_scaled

# %%
sino_int.describe()
# Out:
#             Open       High        Low      Close         Volume  \
# count  32.000000  32.000000  32.000000  32.000000      32.000000
# mean   38.920578  38.930244  38.910500  38.919572   86292.562500
# std     1.169507   1.169478   1.167246   1.165729  164426.826047
# min    35.955002  35.959999  35.950001  35.959499       0.000000
# 25%    38.523751  38.557501  38.522501  38.552675   16454.750000
# 50%    39.062500  39.070000  39.055000  39.067499   38495.500000
# 75%    39.887501  39.898101  39.855001  39.863424   86753.750000
# max    40.240002  40.250000  40.240002  40.244999  916496.000000
#
#          N of Tweet   sum of Nlike  median of Nlike  avg of Nlike  \
# count     32.000000      32.000000        32.000000     32.000000
# mean   19547.020833  252855.177083         0.750000     12.663530
# std     4978.511955  127596.530727         0.439941      4.608707
# min    10030.000000   93361.000000         0.000000      7.408933
# 25%    17028.000000  161352.500000         0.750000      9.276677
# 50%    19215.500000  223902.333333         1.000000     11.192285
# 75%    22640.750000  313291.750000         1.000000     15.548817
# max    34397.000000  656009.333333         1.000000     26.920935
#
#         max of Nlike  sum of retweet  median of retweet  avg of retweet  \
# count      32.000000       32.000000               32.0       32.000000
# mean    56462.875000    43643.916667                0.0        2.161129
# std     90032.685494    22429.254853                0.0        0.757289
# min      5921.000000    12130.000000                0.0        1.110196
# 25%     15631.000000    28435.250000                0.0        1.632236
# 50%     25111.500000    37697.333333                0.0        2.048869
# 75%     61623.750000    52828.000000                0.0        2.575816
# max    488479.000000   101172.000000                0.0        3.770449
#
#        max of retweet  sum of reply  median of reply  avg of reply  \
# count        32.00000     32.000000             32.0     32.000000
# mean       7216.12500  23262.125000              0.0      1.180315
# std        7431.56409   7543.819052              0.0      0.190364
# min         632.00000  10162.000000              0.0      0.867997
# 25%        2183.25000  18348.500000              0.0      1.038296
# 50%        5268.50000  21689.000000              0.0      1.148276
# 75%        9953.00000  29421.750000              0.0      1.327442
# max       37449.00000  40555.000000              0.0      1.562189
#
#        max of reply       Comp
# count     32.000000  32.000000
# mean    2373.375000   0.553031
# std     1992.696095   0.230005
# min      267.000000   0.000000
# 25%      705.750000   0.391063
# 50%     2029.000000   0.562062
# 75%     3083.000000   0.725565
# max     7630.000000   1.000000

# %% [markdown]
# # Save Data

# %%
sino_int.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 0 to 31
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Datetime           32 non-null     datetime64[ns]
#  1   Open               32 non-null     float64
#  2   High               32 non-null     float64
#  3   Low                32 non-null     float64
#  4   Close              32 non-null     float64
#  5   Volume             32 non-null     int64
#  6   N of Tweet         32 non-null     float64
#  7   sum of Nlike       32 non-null     float64
#  8   median of Nlike    32 non-null     int64
#  9   avg of Nlike       32 non-null     float64
#  10  max of Nlike       32 non-null     int64
#  11  sum of retweet     32 non-null     float64
#  12  median of retweet  32 non-null     int64
#  13  avg of retweet     32 non-null     float64
#  14  max of retweet     32 non-null     int64
#  15  sum of reply       32 non-null     float64
#  16  median of reply    32 non-null     int64
#  17  avg of reply       32 non-null     float64
#  18  max of reply       32 non-null     int64
#  19  Comp               32 non-null     float64
#  20  day_of_week        32 non-null     object
# dtypes: datetime64[ns](1), float64(12), int64(7), object(1)
# memory usage: 5.5+ KB

# %%
os.chdir(os.getcwd())
work_folder = "C:\\Users\\Utente\\Esercitazioni DataMan\\Dm_project\\Scripts\\DataMan_project\\Dataset_integrati\\Pfe\\"
sino_int.to_csv(work_folder+'pfe_D_integrato.csv', sep=';')
