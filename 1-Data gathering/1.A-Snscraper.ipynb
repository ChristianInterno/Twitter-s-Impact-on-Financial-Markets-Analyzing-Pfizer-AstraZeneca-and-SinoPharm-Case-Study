# %% [markdown]
# Link di riferimento per l'articolo: https://betterprogramming.pub/how-to-scrape-tweets-with-snscrape-90124ed006af
#
#
# Link riferimento notebook per scrapare: https://github.com/MartinBeckUT/TwitterScraper/tree/master/snscrape

# %%
#come installare la libreria
# !pip install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to c:\users\pier\appdata\local\temp\pip-req-build-67pqknlj
# ...
#   Created wheel for snscrape: filename=snscrape-0.3.5.dev114+g54588e9-py3-none-any.whl size=51141 sha256=e3dbaab8df6a7ab597fb0574ca80f588cb98f0fd6e81a7bec01ebfa75d5f9eee
#   Stored in directory: C:\Users\pier\AppData\Local\Temp\pip-ephem-wheel-cache-dng0rta7\wheels\92\42\87\33fa9b18f7a75d02643a9ca3743339aec9be28c6796267c7d8
# Successfully built snscrape

# %% [markdown]
# *________________________________________________________________________________________________________________________________________________*

# %%
#importo le librerie di riferimento

# %%
# Imports
import snscrape.modules.twitter as sntwitter
import pandas as pd
import os
import datetime

# %%
#Pfizer
# Setting variables to be used below
# Setto il numero massimo di tweet che decido di esttrarre 
maxTweets = 10000000

# Creating list to append tweet data to
# Creo una lista nella quale inserirò i tweet
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
# Utilizzo TwitterSearchScraper per estrarre i tweet con i diversi parametri scelti
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('pfizer lang:"en" since:2021-04-01 until:2021-05-25').get_items()):
    if i>maxTweets:
        break
    tweets_list2.append({
        "data":tweet.date,
        "location":tweet.user.location,
        "id":tweet.id, 
        "testo":tweet.content, 
        "username":tweet.user.username,
        "replyCount":tweet.replyCount,
        "like":tweet.likeCount,
        "retweet_count":tweet.retweetCount,
        "quoteCount":tweet.quoteCount,
        "quote":tweet.quoteCount,
        "source":tweet.source,
        "lang":tweet.lang,
        "url":tweet.url,
        "coordinates":tweet.coordinates,
        "place":tweet.place,
        
        "followersCount":tweet.user.followersCount,
        "friendsCount":tweet.user.followersCount,
        
        "statusesCount":tweet.user.statusesCount,
        "favouritesCount":tweet.user.favouritesCount, 
        "listedCount":tweet.user.listedCount,
        "mediaCount":tweet.user.mediaCount,
    })

# %%
#converto la lista in un dataframe

# %%
pfizer1 = pd.DataFrame(tweets_list2)

# %%
#visualizzo il risultato dell'estrazione

# %%
pfizer1
# Out:
#                              data        location                   id  \
# 0       2021-05-24 23:59:51+00:00       Clyde, NJ  1396979289866870786
# 1       2021-05-24 23:59:48+00:00       Australia  1396979276084236289
# 2       2021-05-24 23:59:43+00:00         florida  1396979253074354176
# 3       2021-05-24 23:59:42+00:00                  1396979250427613184
# 4       2021-05-24 23:59:42+00:00  Los Angeles CA  1396979250150838276
# ...                           ...             ...                  ...
# 1016645 2021-04-01 00:00:04+00:00     Bedford, TX  1377410396303200258
# 1016646 2021-04-01 00:00:02+00:00    Florida, USA  1377410388317282304
# 1016647 2021-04-01 00:00:00+00:00   Eastern Idaho  1377410382701076483
# 1016648 2021-04-01 00:00:00+00:00       Omaha, NE  1377410381086347267
# 1016649 2021-04-01 00:00:00+00:00       Omaha, NE  1377410380981501956
#
#                                                      testo         username  \
# ...

# %%
#salvo quindi il dataframe

# %%
pfizer1.to_csv('phizer_finale.csv', sep=',', index=False)

# %%
#Astrazenca
# Setting variables to be used below
# Setto il numero massimo di tweet che decido di esttrarre
maxTweets = 1000000000

# Creating list to append tweet data to
# Creo una lista nella quale inserirò i tweet
tweets_list3 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
# Utilizzo TwitterSearchScraper per estrarre i tweet con i diversi parametri scelti
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('astrazeneca lang:"en" since:2021-04-01 until:2021-05-25').get_items()):
    if i>maxTweets:
        break
    tweets_list3.append({
        "data":tweet.date,
        "location":tweet.user.location,
        "id":tweet.id, 
        "testo":tweet.content, 
        "username":tweet.user.username,
        "replyCount":tweet.replyCount,
        "like":tweet.likeCount,
        "retweet_count":tweet.retweetCount,
        "quoteCount":tweet.quoteCount,
        "quote":tweet.quoteCount,
        "source":tweet.source,
        "lang":tweet.lang,
        "url":tweet.url,
        "coordinates":tweet.coordinates,
        "place":tweet.place,
        
        "followersCount":tweet.user.followersCount,
        "friendsCount":tweet.user.followersCount,
        
        "statusesCount":tweet.user.statusesCount,
        "favouritesCount":tweet.user.favouritesCount, 
        "listedCount":tweet.user.listedCount,
        "mediaCount":tweet.user.mediaCount,
    })

# %%
#converto la lista in un dataframe

# %%
astrazen1 = pd.DataFrame(tweets_list3)

# %%
#visualizzo il risultato dell'estrazione

# %%
astrazen1
# Out:
#                             data                  location  \
# 0      2021-05-24 23:59:52+00:00                 Australia
# 1      2021-05-24 23:58:33+00:00                  Adelaide
# 2      2021-05-24 23:58:23+00:00  Cable Beach Australia 🇦🇺
# 3      2021-05-24 23:58:02+00:00  Cable Beach Australia 🇦🇺
# 4      2021-05-24 23:57:08+00:00  Cable Beach Australia 🇦🇺
# ...                          ...                       ...
# 343671 2021-04-01 00:00:21+00:00
# 343672 2021-04-01 00:00:21+00:00             Delco/Chesco
# 343673 2021-04-01 00:00:12+00:00
# 343674 2021-04-01 00:00:01+00:00
# 343675 2021-04-01 00:00:00+00:00                    London
#
#                          id  \
# 0       1396979292190371842
# 1       1396978960504815616
# 2       1396978918754635776
# 3       1396978829957074946
# 4       1396978603259170817
# ...                     ...
# 343671  1377410469795782662
# 343672  1377410466851381250
# 343673  1377410431707344896
# 343674  1377410385095974913
# ...

# %%
#salvo quindi il dataframe

# %%
astrazen1.to_csv('astrazen_finale.csv', sep=',', index=False)

# %% [markdown]
# astrazen1.to_csv('astrazeneca.csv', sep=',', index=False)

# %%
#Sinopharm
# Setting variables to be used below
# Setto il numero massimo di tweet che decido di esttrarre

maxTweets = 100000000000

# Creating list to append tweet data to
# Creo una lista nella quale inserirò i tweet
tweets_list4 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
# Utilizzo TwitterSearchScraper per estrarre i tweet con i diversi parametri scelti
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('sinopharm lang:"en" since:2021-04-01 until:2021-05-25').get_items()):
    if i>maxTweets:
        break
    tweets_list4.append({
        "data":tweet.date,
        "location":tweet.user.location,
        "id":tweet.id, 
        "testo":tweet.content, 
        "username":tweet.user.username,
        "replyCount":tweet.replyCount,
        "like":tweet.likeCount,
        "retweet_count":tweet.retweetCount,
        "quoteCount":tweet.quoteCount,
        "quote":tweet.quoteCount,
        "source":tweet.source,
        "lang":tweet.lang,
        "url":tweet.url,
        "coordinates":tweet.coordinates,
        "place":tweet.place,
        
        "followersCount":tweet.user.followersCount,
        "friendsCount":tweet.user.followersCount,
        
        "statusesCount":tweet.user.statusesCount,
        "favouritesCount":tweet.user.favouritesCount, 
        "listedCount":tweet.user.listedCount,
        "mediaCount":tweet.user.mediaCount,
    })

# %%
#converto la lista in un dataframe

# %%
sinopha1 = pd.DataFrame(tweets_list4)

# %%
#visualizzo il risultato dell'estrazione

# %%
sinopha1
# Out:
#                            data           location                   id  \
# 0     2021-05-24 23:56:36+00:00    Toronto, Canada  1396978468794118144
# 1     2021-05-24 23:53:37+00:00    Toronto, Canada  1396977717967458304
# 2     2021-05-24 23:50:46+00:00  Goderich, Ontario  1396977000691212291
# 3     2021-05-24 23:47:57+00:00          Australia  1396976294798131202
# 4     2021-05-24 23:43:51+00:00          Australia  1396975262290505728
# ...                         ...                ...                  ...
# 26688 2021-04-01 00:19:00+00:00                     1377415163632963584
# 26689 2021-04-01 00:17:24+00:00                     1377414761143406593
# 26690 2021-04-01 00:11:43+00:00                     1377413330684444674
# 26691 2021-04-01 00:06:04+00:00           Manitoba  1377411907368316928
# 26692 2021-04-01 00:00:36+00:00     Beijing, China  1377410532857180169
#
#                                                    testo         username  \
# ...

# %%
#salvo quindi il dataframe

# %%
sinopha1.to_csv('sinopharm_finale.csv', sep=',', index=False)
